# %%
from newsapi import NewsApiClient
from langchain.document_loaders import JSONLoader
from dotenv import load_dotenv
import os
import json
load_dotenv()



client = NewsApiClient( api_key = os.getenv("NEWS_API") )
results = client.get_everything( q = "cricket" )
all_news = []
for article in results.get("articles"):
    source = article.get("source").get("name")
    published = article.get("publishedAt")
    title = article.get("title")
    content = article.get("content")
    all_news.append({
        "title" : title , 
        "source" : source , 
        "published" : published , 
        "content" : content
    })

# %%
len(all_news)
# Out:
# 98

# %%
with open( "results.json" , "w" ) as f :
    json.dump( all_news , f )

# %%
loader = JSONLoader( "results.json" , jq_schema = ".[].title, .[].source, .[].published, .[].content" )
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 1}, page_content="England mishandled 'pin-up girl' Wong - Robinson"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 2}, page_content="India v Pakistan: Cricket's ultimate grudge match in the desert"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 3}, page_content="England seamer Cross out of Women's Ashes Test"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 4}, page_content='How to Watch 2025 ICC Champions Trophy Cricket Live From Anywhere'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 5}, page_content='England did not lose because of athleticism - Lewis'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 6}, page_content='Latham and Young tons help New Zealand hammer Pakistan'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 7}, page_content="Angry neighbours dub inflatable dome 'enormous zit'"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 8}, page_content="'Why we're selling family castle after 700 years'"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 9}, page_content='Cricket is owned by AT&T, but what’s the difference and which is a better deal?'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 10}, page_content='Watch a Frog Walk on Water with High-Speed Belly Flops'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 11}, page_content='2025 ICC Champions Trophy Livestream: How to Watch the Cricket Tournament Online'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 12}, page_content='This cricket-mad country spent years convincing international teams it was safe to come play. Now the party is in full swing'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 13}, page_content='Like T-Mobile? You can pay your phone bill by playing games'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 14}, page_content='Afghan women to get support from refugee fund'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 15}, page_content='Australia spinner reported for suspect bowling action'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 16}, page_content='ICC Champions Trophy: Prize pot to climb to $6.9m'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 17}, page_content='Video: Tight security ahead of Pakistan’s first ICC tournament in decades'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 18}, page_content='ICC Champions Trophy 2025: Australia beat England in record chase'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 19}, page_content='Champions Trophy 2025: Is this Pakistan sport’s moment to shine, finally?'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 20}, page_content='ICC Champions Trophy 2025 schedule: Matches, start time, India vs Pakistan'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 21}, page_content='My kids prefer their father to me. It felt unfair until I realized it was a blessing in disguise.'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 22}, page_content="Joyce to step down as Ireland women's head coach"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 23}, page_content='Australia batter Smith passes 10,000 Test runs'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 24}, page_content='Afghanistan ignoring debate caused by boycott calls'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 25}, page_content='ICC Champions Trophy 2025: Pakistan’s ‘punishment’ ends as cricket is back'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 26}, page_content='England down India to keep T20 series alive'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 27}, page_content='Afghan women cricketers reunite in first game after fleeing Taliban'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 28}, page_content='Brave sale values Hundred teams at more than £900m'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 29}, page_content='AT&T will pay you up to $800 per line to switch from your current carrier'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 30}, page_content='India beat England to seal T20 cricket series as sub Rana vexes Buttler'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 31}, page_content='Tech consortium agrees £145m stake in London Spirit'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 32}, page_content='WCA CEO Advocates For A “Systematic” Way To Support Afghanistan Women’s Team'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 33}, page_content='As The U.S. Steals The Spotlight, China Dreams Of Olympic Qualification In Cricket'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 34}, page_content='ICC Champions Trophy 2025: Teams, schedule, venues, tickets, how to stream'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 35}, page_content="'A huge amount to offer' - why have England promoted Smith?"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 36}, page_content='IPL schedule, fixtures announced for the 2025 tournament'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 37}, page_content='ICC Champions Trophy: Top 5 players; Afridi, Azam, Buttler, Gill, Maxwell'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 38}, page_content='Future Remains Uncertain For Sri Lanka In Test Cricket'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 39}, page_content='Huge Ticket Demand For India-Pakistan Champions Trophy Cricket Blockbuster'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 40}, page_content='The CEOs of Microsoft and Alphabet have bought part of the London Hundred cricket franchise'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 41}, page_content='Afghanistan Women’s Cricket Team To Take Field With Pride But Thorny Issue Remains In A Stalemate'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 42}, page_content="'Justify' Hundred expansion, says Originals chair"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 43}, page_content="Future Hundred expansion a 'no brainer' - ECB"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 44}, page_content='Jasprit Bumrah, Amelia Kerr named ICC Cricketers of the Year'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 45}, page_content='Why Cricket’s $6.9 Million Champions Trophy Has Been Revived'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 46}, page_content='Australia Move Closer To Test Cricket Greatness After Crushing Sri Lanka'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 47}, page_content='Cricket Chief Geoff Allardice Steps Down As The Search Starts For His Successor'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 48}, page_content='A Biologist Explains The Animal Combat Sport Of ‘Cricket Fighting’—Invented 1500 Years Ago And Still Played In This Asian Nation'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 49}, page_content='ICC Champions Trophy 2025: Pakistan and India prepare blockbuster showdown'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 50}, page_content='Australia’s PM denies double standard after alleged attacks on Muslim women'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 51}, page_content='NFL Heading To Australia In 2026: Los Angeles Rams To Host First Regular Season Game In Melbourne'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 52}, page_content='Lucrative Women’s Premier League In India Continues To Positively Effect Cricket'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 53}, page_content='A Boy and Transcendent Thinking'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 54}, page_content='Does Anyone Care About Cricket’s Odd One Out, The Champions Trophy?'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 55}, page_content='Rams to host first NFL game in Australia in 2026'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 56}, page_content='Stoinis retires from ODIs on eve of Champions Trophy'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 57}, page_content='Donald Trump: Kristi Noem wird Heimatschutzministerin der USA'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 58}, page_content="Australia's Starc opts out of Champions Trophy"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 59}, page_content="Australia's MCG to host annual NFL game from 2026"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 60}, page_content='Nilesh Shah advises investors to focus on quality, avoid smallcap SIPs amid market uncertainty'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 61}, page_content='Moto G 2025 review: So much better than I expected'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 62}, page_content='The Hundred Sells Out To Boost Profile And English Cricket’s Future'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 63}, page_content='ICC Champions Trophy 2025: Bangladesh vs India: Start, teams, preview'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 64}, page_content='Moto G Power 2025 review: A solid $300 phone'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 65}, page_content='Kettlewell resigns as Motherwell manager'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 66}, page_content='ICC Champions Trophy 2025: India-Pakistan and two other matches to watch'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 67}, page_content='ICC Champions Trophy 2025: Afghanistan lose warm-up match to New Zealand'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 68}, page_content='ICC Champions Trophy 2025 history: Winners, India vs Pakistan, top players'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 69}, page_content='Brighton reject £54m bid from Al Nassr for Mitoma'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 70}, page_content='Who Does Korra End Up With In The Avatar Universe?'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 71}, page_content='ICC Champions Trophy 2025: Blow to Pakistan as Zaman out of tournament'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 72}, page_content="Urvil Patel, bowlers lead Saurashtra's demolition in Sheldon Jackson's farewell game"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 73}, page_content='YouTube ist das neue Fernsehen – Mobile verliert gegen TV-Bildschirme'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 74}, page_content='Gerrard set to leave role as Al Ettifaq manager'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 75}, page_content='Tel rejects Spurs move after £50m deal agreed with Bayern'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 76}, page_content='Man City defender Walker joins AC Milan on loan'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 77}, page_content='مثل فیلم\u200cهای جیسون بورن؛ چگونه زنان کریکت افغانستان از دست طالبان گریختند'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 78}, page_content='Afghanistan fast bowler Shapoor Zadran retires from international cricket'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 79}, page_content="Lord's reshapes global role as Jay Shah joins new MCC advisory board"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 80}, page_content='McDonald credits Kuhnemann recovery, Dubai training camp for Galle rout'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 81}, page_content='Rickelton stars in South Africa win over Afghanistan'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 82}, page_content='England Annihilated In Adelaide As Australia Dominate Women’s Ashes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 83}, page_content='Australia’s Second String Mutes England In Champions Trophy Win'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 84}, page_content='ICC Champions Trophy 2025: Who will win the tournament?'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 85}, page_content='ICC Champions Trophy 2025: India’s Gill steers nervy win against Bangladesh'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 86}, page_content='ICC Champions Trophy 2025: Pakistan crushed by New Zealand in opening game'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 87}, page_content="Tendulkar to receive BCCI's lifetime achievement award; Bumrah, Mandhana win big"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 88}, page_content='Khawaja defends cricket journalist who was dumped over Palestinian posts'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 89}, page_content='Papers: Watkins open to Arsenal move as Villa eye Asensio'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 90}, page_content="Williamson hails 'outstanding' Conway after record partnership"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 91}, page_content="How the WBBL and WPL franchises are shaping women's cricket"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 92}, page_content='Ranji Trophy: Kuldeep Yadav in UP squad for their last league match'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 93}, page_content="ICC bans Bangladesh's Shohely Akhter on corruption charges"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 94}, page_content='Sophie Devine to miss ODIs and T20Is against Sri Lanka'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 95}, page_content='Garmin Instinct 3 vs. 2X vs. 2: Every key upgrade'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 96}, page_content='Chelsea striker Kerr cleared of racially aggravated harassment'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 97}, page_content="Afghanistan women's match a big step on a path unknown"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 98}, page_content='Netflix Unveils India Originals Slate For 2025 Including ‘Dining With The Kapoors’, ‘Akka’ & ‘The Ba***ds of Bollywood’'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 99}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 100}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 101}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 102}, page_content='CNET'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 103}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 104}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 105}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 106}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 107}, page_content='Android Authority'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 108}, page_content='Scientific American'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 109}, page_content='Variety'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 110}, page_content='Yahoo Entertainment'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 111}, page_content='Digital Trends'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 112}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 113}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 114}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 115}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 116}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 117}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 118}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 119}, page_content='Business Insider'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 120}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 121}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 122}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 123}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 124}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 125}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 126}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 127}, page_content='Android Authority'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 128}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 129}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 130}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 131}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 132}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 133}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 134}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 135}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 136}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 137}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 138}, page_content='TechRadar'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 139}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 140}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 141}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 142}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 143}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 144}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 145}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 146}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 147}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 148}, page_content='Al Jazeera English'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 149}, page_content='Deadline'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 150}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 151}, page_content='Psychology Today'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 152}, page_content='Forbes'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 153}, page_content='ESPN'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 154}, page_content='BBC News'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 155}, page_content='Die Zeit'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num':
chars]"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 386}, page_content="NewsHe is making a return after a hernia surgery and hasn't played competitive cricket since October 2024"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 387}, page_content='NewsAkhter, who last turned out for Bangladesh in 2022, has been banned for five years from all cricket'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 388}, page_content='NewsShe had taken a break from domestic cricket and withdrawn from the WPL previously to "prioritise her well-being"'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 389}, page_content="Comparing the Garmin Instinct 3 vs. 2 is more complicated than you'd think. The Garmin Instinct 3 has both AMOLED and MIP Solar versions in multiple sizes, each with a different battery life. The Gar… [+18316 chars]"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 390}, page_content='Chelsea striker Sam Kerr has been found not guilty of racially aggravated harassment towards a police officer.\r\nThe Australia international called PC Stephen Lovell "stupid and white" during an incid… [+1875 chars]'),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 391}, page_content="NewsThursday's fixture against Cricket Without Borders is their first as a team, what will that team look like in future?"),
#  Document(metadata={'source': 'C:\\Users\\hp\\Desktop\\python practice\\Explore\\day-15\\results.json', 'seq_num': 392}, page_content='Netflix has unveiled new Indian originals today for 2025, after releasing teasers of previously-announced projects over the last few weeks. \r\nNew tentpole projects include Aryan Khan’s Bollywood-them… [+1784 chars]')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.prompts import ChatPromptTemplate
from langchain_ollama.embeddings import OllamaEmbeddings
from langchain_google_genai.llms import GoogleGenerativeAI
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains.retrieval import create_retrieval_chain

# %%
text_splitter = RecursiveCharacterTextSplitter( chunk_size = 1000 , chunk_overlap = 200 )
splits = text_splitter.split_documents(data)

# %%
embeddings_model = OllamaEmbeddings( model = "nomic-embed-text:latest" )
db = Chroma.from_documents( splits , embeddings_model )
retriever = db.as_retriever()

# %%
prompt = ChatPromptTemplate.from_template(
    """
You are an expert at providing news in a documented manner,
Based on the given context give the news to the user with respected details.
Context:
{context}
Question:
{input}
"""
)
llm = GoogleGenerativeAI( model = "gemini-2.0-flash" )

combine_chain = create_stuff_documents_chain( llm = llm , prompt = prompt )
retrieval_chain = create_retrieval_chain( retriever = retriever , combine_docs_chain = combine_chain )

# %%
res = retrieval_chain.invoke({"input":"Give me news related to the champions trophy"})

# %%
res["answer"]
# Out:
# "Here's a news report summarizing the key details about the upcoming ICC Champions Trophy:\n\n**ICC Champions Trophy Returns with Increased Prize Money**\n\nThe ICC Champions Trophy is set to begin on Wednesday in Pakistan and Dubai, United Arab Emirates, featuring the world's top eight cricket teams vying for the title. The International Cricket Council (ICC) has announced a significant increase in the prize pool for this year's tournament, raising it to $6.9 million. This represents a 53% jump from the 2017 edition. The winning team will receive $2.24 million.\n"

# %% [markdown]
# "Here's a news report summarizing the key details about the upcoming ICC Champions Trophy:\n\n**ICC Champions Trophy Returns with Increased Prize Money**\n\nThe ICC Champions Trophy is set to begin on Wednesday in Pakistan and Dubai, United Arab Emirates, featuring the world's top eight cricket teams vying for the title. The International Cricket Council (ICC) has announced a significant increase in the prize pool for this year's tournament, raising it to $6.9 million. This represents a 53% jump from the 2017 edition. The winning team will receive $2.24 million.\n"
